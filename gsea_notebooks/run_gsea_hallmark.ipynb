# %%
import pandas as pd
import gseapy as gp
from pathlib import Path
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from scipy.spatial.distance import pdist

# %%
hallmark_gmt = "gsea_gene_set/h.all.v2025.1.Hs.symbols.gmt"
spectra_dir = Path("all_datasets_consensus/anal_pc5_c21_S1.filtered_consensus_outputs") 
out_dir = Path("gsea_results_S1_C8")
out_dir.mkdir(parents=True, exist_ok=True)

# %%
# If True: writes one CSV per (K, GEP). Can be lots of files.
write_per_gep_files = False

# GSEA parameters
min_size = 15
max_size = 500
permutation_num = 1000
seed = 42

# %% [markdown]
# find files + parse K

# %%
pattern = re.compile(r"\.gene_spectra_score\.k_(\d+)\.dt_0_01\.txt$")

spectra_files = []
for fp in spectra_dir.glob("*.gene_spectra_score.k_*.dt_0_01.txt"):
    m = pattern.search(fp.name)
    if m:
        K = int(m.group(1))
        spectra_files.append((K, fp))

if not spectra_files:
    raise FileNotFoundError(
        f"No files matched '*.gene_spectra_score.k_*.dt_0_01.txt' in {spectra_dir}"
    )

spectra_files.sort(key=lambda x: x[0])

all_rows = []

# %% [markdown]
# run gsea

# %%
for K, fp in spectra_files:
    print(f"Loading K={K}: {fp.name}")
    spectra = pd.read_csv(fp, sep="\t", index_col=0)  # rows=GEPs, cols=genes

    # Optional: ensure gene names are strings
    spectra.columns = spectra.columns.astype(str)

    for gep in spectra.index:
        # Create preranked list: genes sorted by score
        rnk = spectra.loc[gep].sort_values(ascending=False)

        # gseapy accepts: pd.Series with index=gene, values=score
        prerank_res = gp.prerank(
            rnk=rnk,
            gene_sets=hallmark_gmt,
            min_size=min_size,
            max_size=max_size,
            permutation_num=permutation_num,
            seed=seed,
            outdir=None,      # no auto-folder per run
            verbose=False
        )

        res = prerank_res.res2d.copy()
        res["K"] = K
        res["GEP"] = str(gep)
        res["spectra_file"] = fp.name

        # Standardize column names a bit (gseapy uses varying headers by version)
        # Common columns: 'Term','NES','NOM p-val','FDR q-val','ES','Lead_genes'
        # Keep what exists.
        keep_cols = ["K", "GEP", "spectra_file"] + [c for c in res.columns if c not in ["K", "GEP", "spectra_file"]]
        res = res[keep_cols]

        all_rows.append(res)

        if write_per_gep_files:
            out_csv = out_dir / f"K{K}_{gep}_hallmark_gsea.csv"
            res.to_csv(out_csv, index=False)
# Out:
# 2026-01-15 14:31:22,049 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=5: anal_pc5_c21_S1.filtered.gene_spectra_score.k_5.dt_0_01.txt
# 2026-01-15 14:31:22,363 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:22,658 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:22,942 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:23,227 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:23,557 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=6: anal_pc5_c21_S1.filtered.gene_spectra_score.k_6.dt_0_01.txt
# 2026-01-15 14:31:23,840 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:24,118 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:24,407 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:24,701 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:24,994 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:25,320 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=7: anal_pc5_c21_S1.filtered.gene_spectra_score.k_7.dt_0_01.txt
# 2026-01-15 14:31:25,616 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:25,917 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:26,209 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:26,514 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:26,818 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:27,114 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:27,404 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=8: anal_pc5_c21_S1.filtered.gene_spectra_score.k_8.dt_0_01.txt
# 2026-01-15 14:31:27,686 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:27,972 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:28,273 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:28,572 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:28,858 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:29,147 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:29,437 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:29,756 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=9: anal_pc5_c21_S1.filtered.gene_spectra_score.k_9.dt_0_01.txt
# 2026-01-15 14:31:30,044 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:30,335 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:30,628 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:30,919 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:31,205 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:31,498 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:31,788 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:32,096 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:32,440 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=10: anal_pc5_c21_S1.filtered.gene_spectra_score.k_10.dt_0_01.txt
# 2026-01-15 14:31:32,756 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:33,074 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:33,372 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:33,668 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:33,974 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:34,281 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:34,600 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:34,904 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:35,200 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:35,540 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=11: anal_pc5_c21_S1.filtered.gene_spectra_score.k_11.dt_0_01.txt
# 2026-01-15 14:31:35,856 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:36,162 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:36,469 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:36,773 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:37,081 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:37,388 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:37,681 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:38,004 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:38,305 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:38,607 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:38,929 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=12: anal_pc5_c21_S1.filtered.gene_spectra_score.k_12.dt_0_01.txt
# 2026-01-15 14:31:39,230 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:39,529 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:39,825 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:40,122 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:40,421 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:40,714 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:41,001 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:41,287 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:41,578 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:41,871 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:42,173 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:42,536 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=13: anal_pc5_c21_S1.filtered.gene_spectra_score.k_13.dt_0_01.txt
# 2026-01-15 14:31:42,836 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:43,155 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:43,527 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:43,883 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:44,201 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:44,518 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:44,831 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:45,129 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:45,427 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:45,728 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:46,031 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:46,322 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:46,650 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=14: anal_pc5_c21_S1.filtered.gene_spectra_score.k_14.dt_0_01.txt
# 2026-01-15 14:31:46,944 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:47,237 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:47,541 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:47,835 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:48,135 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:48,425 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:48,729 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:49,054 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:49,352 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:49,645 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:49,938 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:50,236 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:50,540 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:50,879 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=15: anal_pc5_c21_S1.filtered.gene_spectra_score.k_15.dt_0_01.txt
# 2026-01-15 14:31:51,187 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:51,485 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:51,798 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:52,103 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:52,403 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:52,700 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:52,988 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:53,283 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:53,579 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:53,894 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:54,201 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:54,507 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:54,801 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:55,086 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:55,420 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=16: anal_pc5_c21_S1.filtered.gene_spectra_score.k_16.dt_0_01.txt
# 2026-01-15 14:31:55,718 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:56,013 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:56,310 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:56,615 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:56,921 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:57,234 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:57,520 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:57,839 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:58,143 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:58,448 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:58,751 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:59,055 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:59,377 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:59,695 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:31:59,995 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:00,334 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=17: anal_pc5_c21_S1.filtered.gene_spectra_score.k_17.dt_0_01.txt
# 2026-01-15 14:32:00,644 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:00,947 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:01,242 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:01,544 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:01,841 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:02,134 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:02,425 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:02,698 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:02,994 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:03,290 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:03,593 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:03,897 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:04,199 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:04,511 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:04,806 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:05,101 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:05,428 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=18: anal_pc5_c21_S1.filtered.gene_spectra_score.k_18.dt_0_01.txt
# 2026-01-15 14:32:05,733 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:06,040 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:06,332 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:06,624 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:06,914 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:07,211 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:07,516 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:07,831 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:08,141 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:08,445 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:08,743 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:09,038 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:09,343 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:09,648 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:09,943 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:10,245 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:10,559 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:10,897 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=19: anal_pc5_c21_S1.filtered.gene_spectra_score.k_19.dt_0_01.txt
# 2026-01-15 14:32:11,193 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:11,492 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:11,792 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:12,092 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:12,387 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:12,685 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:12,991 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:13,279 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:13,566 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:13,865 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:14,159 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:14,475 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:14,784 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:15,086 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:15,378 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:15,688 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:15,992 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:16,279 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:16,612 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=20: anal_pc5_c21_S1.filtered.gene_spectra_score.k_20.dt_0_01.txt
# 2026-01-15 14:32:16,920 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:17,212 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:17,501 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:17,796 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:18,124 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:18,428 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:18,738 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:19,037 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:19,336 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:19,637 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:19,938 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:20,235 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:20,541 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:20,842 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:21,137 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:21,442 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:21,734 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:22,042 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:22,344 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:22,691 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# Loading K=21: anal_pc5_c21_S1.filtered.gene_spectra_score.k_21.dt_0_01.txt
# 2026-01-15 14:32:22,999 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:23,302 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:23,606 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:23,917 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:24,215 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:24,519 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:24,822 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:25,122 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:25,426 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:25,727 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:26,049 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:26,342 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:26,615 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:26,913 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:27,212 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:27,510 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:27,824 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:28,129 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:28,452 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-01-15 14:32:28,756 [WARNING] Duplicated values found in preranked stats: 0.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.

# %%
summary = pd.concat(all_rows, ignore_index=True)

# Make the most useful subset table (if columns exist)
col_map = {}
for c in summary.columns:
    cl = c.lower()
    if cl == "term":
        col_map[c] = "pathway"
    elif cl == "nes":
        col_map[c] = "NES"
    elif "fdr" in cl and "q" in cl:
        col_map[c] = "FDR_q"
    elif "nom" in cl and "p" in cl:
        col_map[c] = "NOM_p"
    elif cl == "es":
        col_map[c] = "ES"
    elif "lead" in cl:
        col_map[c] = "leading_edge"

summary = summary.rename(columns=col_map)

summary_path = out_dir / "hallmark_gsea_all_K_all_GEPs_tidy.csv"
summary.to_csv(summary_path, index=False)

print(f"\nDONE ✅\nWrote tidy summary to: {summary_path}")
# Out:
# DONE ✅
# Wrote tidy summary to: gsea_results_S1_C8/hallmark_gsea_all_K_all_GEPs_tidy.csv

# %%
summary.shape
# Out:
# (9724, 13)

# %%
for K, sub in summary.groupby("K"):
    out_path = out_dir / f"K{K}_hallmark_gsea.csv"
    sub.to_csv(out_path, index=False)

# %%
# Define significance
sig = summary[
    (summary["FDR_q"] <= 0.25) &
    (summary["NES"].abs() >= 1.5)
]

# Count occurrences across all K and GEPs
pathway_counts = (
    sig.groupby("pathway")
       .size()
       .reset_index(name="count")
       .sort_values("count", ascending=False)
)

pathway_counts
# Out:
#                                        pathway  count
# 12                        HALLMARK_E2F_TARGETS    186
# 17                     HALLMARK_G2M_CHECKPOINT    163
# 1                 HALLMARK_ALLOGRAFT_REJECTION    120
# 13  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION    115
# 26          HALLMARK_INTERFERON_GAMMA_RESPONSE    101
# 14            HALLMARK_ESTROGEN_RESPONSE_EARLY     90
# 15             HALLMARK_ESTROGEN_RESPONSE_LATE     90
# 29                    HALLMARK_MITOTIC_SPINDLE     86
# 9                         HALLMARK_COAGULATION     84
# 25          HALLMARK_INTERFERON_ALPHA_RESPONSE     83
# 32                        HALLMARK_P53_PATHWAY     78
# 40                     HALLMARK_UV_RESPONSE_DN     69
# 3                        HALLMARK_ANGIOGENESIS     68
# 31                         HALLMARK_MYOGENESIS     66
# 16              HALLMARK_FATTY_ACID_METABOLISM     63
# 43              HALLMARK_XENOBIOTIC_METABOLISM     58
# 10                         HALLMARK_COMPLEMENT     55
# 23            HALLMARK_IL6_JAK_STAT3_SIGNALING     50
# 8             HALLMARK_CHOLESTEROL_HOMEOSTASIS     47
# 34            HALLMARK_PI3K_AKT_MTOR_SIGNALING     47
# 39          HALLMARK_UNFOLDED_PROTEIN_RESPONSE     46
# 28                  HALLMARK_KRAS_SIGNALING_UP     46
# 19                 HALLMARK_HEDGEHOG_SIGNALING     42
# 24              HALLMARK_INFLAMMATORY_RESPONSE     40
# 37                 HALLMARK_TGF_BETA_SIGNALING     40
# 38            HALLMARK_TNFA_SIGNALING_VIA_NFKB     39
# 30                   HALLMARK_MTORC1_SIGNALING     38
# 18                         HALLMARK_GLYCOLYSIS     38
# 0                        HALLMARK_ADIPOGENESIS     36
# 4                     HALLMARK_APICAL_JUNCTION     36
# 27                  HALLMARK_KRAS_SIGNALING_DN     30
# 35    HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY     28
# 36                    HALLMARK_SPERMATOGENESIS     28
# 21                            HALLMARK_HYPOXIA     25
# 6                           HALLMARK_APOPTOSIS     24
# 11                         HALLMARK_DNA_REPAIR     22
# 7                HALLMARK_BILE_ACID_METABOLISM     21
# 41                     HALLMARK_UV_RESPONSE_UP     20
# 22                HALLMARK_IL2_STAT5_SIGNALING     17
# 33                         HALLMARK_PEROXISOME     14
# 2                   HALLMARK_ANDROGEN_RESPONSE     14
# 20                    HALLMARK_HEME_METABOLISM      9
# 42         HALLMARK_WNT_BETA_CATENIN_SIGNALING      9
# 5                      HALLMARK_APICAL_SURFACE      5

# %%
pathway_k_counts = (
    sig.groupby("pathway")["K"]
       .nunique()
       .reset_index(name="num_Ks")
       .sort_values("num_Ks", ascending=False)
)

pathway_k_counts
# Out:
#                                        pathway  num_Ks
# 0                        HALLMARK_ADIPOGENESIS      17
# 27                  HALLMARK_KRAS_SIGNALING_DN      17
# 19                 HALLMARK_HEDGEHOG_SIGNALING      17
# 1                 HALLMARK_ALLOGRAFT_REJECTION      17
# 23            HALLMARK_IL6_JAK_STAT3_SIGNALING      17
# 24              HALLMARK_INFLAMMATORY_RESPONSE      17
# 25          HALLMARK_INTERFERON_ALPHA_RESPONSE      17
# 26          HALLMARK_INTERFERON_GAMMA_RESPONSE      17
# 28                  HALLMARK_KRAS_SIGNALING_UP      17
# 17                     HALLMARK_G2M_CHECKPOINT      17
# 29                    HALLMARK_MITOTIC_SPINDLE      17
# 31                         HALLMARK_MYOGENESIS      17
# 32                        HALLMARK_P53_PATHWAY      17
# 34            HALLMARK_PI3K_AKT_MTOR_SIGNALING      17
# 37                 HALLMARK_TGF_BETA_SIGNALING      17
# 40                     HALLMARK_UV_RESPONSE_DN      17
# 18                         HALLMARK_GLYCOLYSIS      17
# 43              HALLMARK_XENOBIOTIC_METABOLISM      17
# 16              HALLMARK_FATTY_ACID_METABOLISM      17
# 4                     HALLMARK_APICAL_JUNCTION      17
# 14            HALLMARK_ESTROGEN_RESPONSE_EARLY      17
# 13  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION      17
# 12                        HALLMARK_E2F_TARGETS      17
# 3                        HALLMARK_ANGIOGENESIS      17
# 10                         HALLMARK_COMPLEMENT      17
# 9                         HALLMARK_COAGULATION      17
# 8             HALLMARK_CHOLESTEROL_HOMEOSTASIS      17
# 7                HALLMARK_BILE_ACID_METABOLISM      17
# 15             HALLMARK_ESTROGEN_RESPONSE_LATE      17
# 38            HALLMARK_TNFA_SIGNALING_VIA_NFKB      16
# 30                   HALLMARK_MTORC1_SIGNALING      16
# 36                    HALLMARK_SPERMATOGENESIS      16
# 39          HALLMARK_UNFOLDED_PROTEIN_RESPONSE      15
# 35    HALLMARK_REACTIVE_OXYGEN_SPECIES_PATHWAY      15
# 22                HALLMARK_IL2_STAT5_SIGNALING      15
# 11                         HALLMARK_DNA_REPAIR      15
# 6                           HALLMARK_APOPTOSIS      13
# 21                            HALLMARK_HYPOXIA      12
# 41                     HALLMARK_UV_RESPONSE_UP      12
# 2                   HALLMARK_ANDROGEN_RESPONSE      10
# 33                         HALLMARK_PEROXISOME       9
# 20                    HALLMARK_HEME_METABOLISM       8
# 42         HALLMARK_WNT_BETA_CATENIN_SIGNALING       8
# 5                      HALLMARK_APICAL_SURFACE       5

# %%
top_n = 50

top_pathways_per_gep = (
    summary
    .sort_values(['K', 'GEP', 'NES'], ascending=[True, True, False])
    .groupby(['K', 'GEP'])
    .head(top_n)
)

# %%
unique_pathways = top_pathways_per_gep['pathway'].unique()
print(f"Total unique pathways in top {top_n} across all GEPs: {len(unique_pathways)}")
# Out:
# Total unique pathways in top 50 across all GEPs: 44

# %%
top_pathways_per_gep = top_pathways_per_gep.copy()
top_pathways_per_gep['GEP_label'] = 'GEP' + top_pathways_per_gep['GEP'].astype(str) + '_k' + top_pathways_per_gep['K'].astype(str)

# %%
heatmap_data = top_pathways_per_gep.pivot_table(
    index='GEP_label',
    columns='pathway',
    values='NES',
    aggfunc='first'
)

# %%
def sort_key(label):
    # Extract GEP number and K from label like "GEP1_k5"
    parts = label.replace('GEP', '').split('_k')
    gep_num = int(parts[0])
    k_val = int(parts[1])
    return (k_val, gep_num)

# %%
heatmap_data = heatmap_data.loc[sorted(heatmap_data.index, key=sort_key)]

# Fill NaN with 0 (pathway not in top 50 for that GEP)
heatmap_data = heatmap_data.fillna(0)

print(f"Heatmap shape: {heatmap_data.shape[0]} GEPs x {heatmap_data.shape[1]} pathways")
# Out:
# Heatmap shape: 221 GEPs x 44 pathways
# /var/folders/bw/grhyggnj06ncywf0093kz3ch0000gn/T/ipykernel_20547/2899401707.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = heatmap_data.fillna(0)

# %%
# Step 5: Create the heatmap
fig, ax = plt.subplots(figsize=(40, 60))

sns.heatmap(
    heatmap_data,
    cmap='RdBu_r',
    center=0,
    xticklabels=True,
    yticklabels=True,
    ax=ax,
    cbar_kws={'label': 'NES'}
)

plt.xlabel('Hallmark Pathway', fontsize=12)
plt.ylabel('GEP', fontsize=12)
plt.title(f'Top {top_n} Hallmark Pathways per GEP (K=5 to K=21)', fontsize=14)

# Rotate x-axis labels for readability
plt.xticks(rotation=90, fontsize=6)
plt.yticks(fontsize=6)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Dark red (NES ~ +3): The pathway's genes are strongly enriched at the TOP of the GEP's ranked gene list — meaning genes in that pathway have high expression/scores in that GEP
# - Dark blue (NES ~ -3): The pathway's genes are strongly enriched at the BOTTOM of the ranked list — meaning those pathway genes are suppressed/low in that GEP
# - White/pale (NES ~ 0): No enrichment — the pathway genes are randomly distributed, not particularly associated with that GEP

# %%
g = sns.clustermap(
    heatmap_data,
    cmap='RdBu_r',
    center=0,
    figsize=(20, 30),
    xticklabels=True,
    yticklabels=True,
    dendrogram_ratio=(0.1, 0.05),  # size of dendrograms (row, col)
    cbar_pos=(0.02, 0.8, 0.03, 0.15),  # colorbar position
    cbar_kws={'label': 'NES'},
    method='ward',  # linkage method - ward minimizes variance
    metric='euclidean',  # distance metric
    row_cluster=True,  # cluster GEPs
    col_cluster=True,  # cluster pathways
)

# Adjust labels
g.ax_heatmap.set_xlabel('Hallmark Pathway', fontsize=12)
g.ax_heatmap.set_ylabel('GEP', fontsize=12)
g.ax_heatmap.tick_params(axis='x', labelsize=6, rotation=90)
g.ax_heatmap.tick_params(axis='y', labelsize=6)

g.fig.suptitle('Hierarchically Clustered Hallmark Pathways x GEPs (K=5 to K=21)', 
               fontsize=14, y=1.01)

plt.show()

# %%
k5_gsea = pd.read_csv('gsea_results_S1_hallmark/K5_hallmark_gsea.csv')
k5_gsea.head()
# Out:
#    K  GEP                                       spectra_file     Name  \
# 0  5    1  anal_pc5_c21_S1.filtered.gene_spectra_score.k_...  prerank
# 1  5    1  anal_pc5_c21_S1.filtered.gene_spectra_score.k_...  prerank
# 2  5    1  anal_pc5_c21_S1.filtered.gene_spectra_score.k_...  prerank
# 3  5    1  anal_pc5_c21_S1.filtered.gene_spectra_score.k_...  prerank
# 4  5    1  anal_pc5_c21_S1.filtered.gene_spectra_score.k_...  prerank
#
#                                       pathway        ES       NES  NOM_p  \
# 0                HALLMARK_ALLOGRAFT_REJECTION  0.709235  2.676501    0.0
# 1  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION -0.556179 -2.461131    0.0
# 2                     HALLMARK_G2M_CHECKPOINT -0.620467 -2.359276    0.0
# 3                        HALLMARK_E2F_TARGETS -0.635617 -2.335318    0.0
# 4                        HALLMARK_COAGULATION -0.544556 -2.135597    0.0
#
#       FDR_q  FWER p-val   Tag %  Gene %  \
# 0  0.000000       0.000  72/121  16.92%
# 1  0.000000       0.000  98/164  22.74%
# 2  0.000000       0.000   59/68  32.74%
# 3  0.000000       0.000   46/54  31.14%
# 4  0.000527       0.001   45/79  26.70%
#
#                                         leading_edge
# 0  ITGAL;CD2;LTB;IL16;CD96;IL2RG;ZAP70;PTPRC;CD3E...
# 1  GPC1;LRP1;DST;MMP14;IGFBP2;TGFBI;FBLN1;PFN2;IG...
# 2  MCM2;SLC12A2;CDK1;TOP2A;TPX2;MEIS1;ODC1;NUSAP1...
# 3  MCM2;MCM4;CDKN2A;CDK1;HELLS;TK1;TOP2A;HMGB2;TC...
# 4  GSN;CTSB;LRP1;MMP14;C1R;C1S;SPARC;A2M;SERPINA1...

# %%
k5_gsea['GEP_label'] = 'GEP' + k5_gsea['GEP'].astype(str)

heatmap_data = k5_gsea.pivot_table(
    index='GEP_label',
    columns='pathway',
    values='NES',
    aggfunc='first'
)

# Create the clustered heatmap
g = sns.clustermap(
    heatmap_data,
    cmap='RdBu_r',
    center=0,
    figsize=(16, 8),
    xticklabels=True,
    yticklabels=True,
    dendrogram_ratio=(0.15, 0.08),
    cbar_pos=(0.02, 0.8, 0.03, 0.15),
    cbar_kws={'label': 'NES'},
    method='ward',
    metric='euclidean',
    row_cluster=True,
    col_cluster=True,
)

# Adjust labels
g.ax_heatmap.set_xlabel('Hallmark Pathway', fontsize=11)
g.ax_heatmap.set_ylabel('Gene Expression Program', fontsize=11)
g.ax_heatmap.tick_params(axis='x', labelsize=7, rotation=90)
g.ax_heatmap.tick_params(axis='y', labelsize=9)

g.fig.suptitle('Hierarchically Clustered Hallmark Pathways x GEPs (K=5)', 
               fontsize=13, y=1.02)
plt.show()

# %%
k5_gsea['GEP_label'] = 'GEP' + k5_gsea['GEP'].astype(str)

heatmap_data = k5_gsea.pivot_table(
    index='GEP_label',
    columns='pathway',
    values='NES',
    aggfunc='first'
)

# Create the clustered heatmap
g = sns.clustermap(
    heatmap_data,
    cmap='RdBu_r',
    center=0,
    figsize=(16, 8),
    xticklabels=True,
    yticklabels=True,
    dendrogram_ratio=(0.15, 0.08),
    cbar_pos=(0.02, 0.8, 0.03, 0.15),
    cbar_kws={'label': 'NES'},
    method='ward',
    metric='euclidean',
    row_cluster=True,
    col_cluster=True,
)

# Adjust labels
g.ax_heatmap.set_xlabel('Hallmark Pathway', fontsize=11)
g.ax_heatmap.set_ylabel('Gene Expression Program', fontsize=11)
g.ax_heatmap.tick_params(axis='x', labelsize=7, rotation=90)
g.ax_heatmap.tick_params(axis='y', labelsize=9)

g.fig.suptitle('Hierarchically Clustered Hallmark Pathways x GEPs (K=5)', 
               fontsize=13, y=1.02)
plt.show()
